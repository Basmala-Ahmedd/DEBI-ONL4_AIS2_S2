# %%
list_One = [1,2,3,4,"depi","Learning",True,[1,2,3,"True",["ML","DL","CV","NLP"]]]

# %%
print(list_One[4])
print(list_One[7][4])
print(list_One[7][4][0]))
# Out:
# depi
# ['ML', 'DL', 'CV', 'NLP']
# ML

# %%
list_One[7][4][0] = "DS"
list_One
# Out:
# [1,
#  2,
#  3,
#  4,
#  'depi',
#  'Learning',
#  True,
#  [1, 2, 3, 'True', ['DS', 'DL', 'CV', 'NLP']]]

# %%
List_i = ["depi","Learning","ML"]
List_i.append("DL")
List_i
# Out:
# ['depi', 'Learning', 'ML', 'DL']

# %%
list_1 = ["depi","learning","ML"]
list_1.append("Dl")
list_1
# Out:
# ['depi', 'learning', 'ML', 'Dl']

# %%
list_1.insert(0,"data")
list_1
# Out:
# ['data', 'depi', 'learning', 'ML', 'Dl']

# %%
list_2 = [1,2,3,4]
list_3 = [5,6,7,8]
list_2.extend(list_3)
list_2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list_new = ["Depi","Learn","Python"]
list_new.remove("Depi")
list_new
# Out:
# ['Learn', 'Python']

# %%
list_new.pop()
# Out:
# 'Python'

# %%
del list_new[0]
list_new
# Out:
# []

# %%
List_i = [1,2,3]
list_j = [4,5,6]
List_k = [7,8,9]
matrix = [List_i,list_j,List_k]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
My_list = ["one","two","three","four",4,6]
My_list[1:4]
# Out:
# ['two', 'three', 'four']

# %%
My_list * 2
My_list
# Out:
# ['one', 'two', 'three', 'four', 4, 6]

# %%
name = input("Enter Your Name : ")
type(name)
name
# Out:
# 'Basmala'

# %%
my_name = input ("Enter Your Name :")
id = input("Enter Your Id :")
print(f"My Name is {my_name} and My Id is {id}")
# Out:
# My Name is Basmala and My Id is 12345

# %%
# Quiz
input_List = ["depi","learning","python"]
item = input ("Enter item to the List : ")
input_List.remove(item)
print(f"The Output List : {input_List}")
# Out:
# The Output List : ['depi', 'python']

# %%
my_list = [1,2,3,3]
index_value = my_list.index(3) #first one it met.
index_value
# Out:
# 2

# %%
my_list = [1,2,3,3]
index_value = my_list.count(3) 
index_value
# Out:
# 2

# %%
list_sort = [3,1,5,7,2,9,4,0]
list_sort.sort()
list_sort
# Out:
# [0, 1, 2, 3, 4, 5, 7, 9]

# %%
list_rev = [3,1,5,7,2,9,4,0]
list_rev.reverse()
list_rev
# Out:
# [0, 4, 9, 2, 7, 5, 1, 3]

# %%
list= [3,1,5,7,2,9,4,0]
list.clear()
list
# Out:
# []

# %%
# Tuple
tuple_1 = (1,2,3)
tuple_1
# Out:
# (1, 2, 3)

# %%
# Set
Set_1 = {"Depi","Learning","Depi"}
Set_1
# Out:
# {'Depi', 'Learning'}

# %%
color = {"red","green","blue"}
color.discard("blue")
color
# Out:
# {'green', 'red'}

# %%
a = {1,2,3}
b = {4,5,6}
print(a.difference(b))
print(a.union(b))
# Out:
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6}

# %%
# Dictionary 
dict_1 = {"key_1":12}
dict_1["key_1"]= "Depi"
dict_1
# Out:
# {'key_1': 'Depi'}

# %%
# Quiz
num_1 = float (input("Enter Num_1 :")) # 10
num_2 = float (input("Enter Num_2 :")) # 5
print(f"Summation : {num_1 + num_2}")
print(f"Subtraction : {num_1 - num_2}")
print(f"Multiplication : {num_1 * num_2}")
print(f"Devision : {num_1 / num_2}")
# Out:
# Summation : 15.0
# Subtraction : 5.0
# Multiplication : 50.0
# Devision : 2.0

# %%
# if-Condition:
a = 200
b = 33
if b > a :
    print ("b is greater than a")
else:
        print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 200
b = 33
if b > a :
    print ("b is greater than a")
elif  a ==  b  :
    print("a is equal to b ")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %%
x = 5
y = 10
if x > 0 and y>0 :
    print("Positive Number")
# Out:
# Positive Number

# %%
x = 5
result = "Even" if x % 2 == 0 else "odd"
print(result)
# Out:
# odd

# %%
a = 10
b = 5
result = a+b if a > b else a-b
print(result)
# Out:
# 15

# %%
age = 21
print("adult") if age >= 18 else (print("Teenager") if age>=13 else print("Child") )
# Out:
# adult

# %%
is_Sunny = True
temp = 25
if is_Sunny :
    print("sunny day")
    if temp > 20 :
        print ("warm")
    else:
        print("Cool")
else :
        print("not Sunnay")
# Out:
# sunny day
# warm

# %%
grade = int(input("Enter Your Grade :"))
if  0 <= grade <= 100 :
    if 90 <= grade <= 100 :
        print("Grade = A") 
    elif 80 <= grade <= 90 :
        print("Grade =B")
    elif 70<= grade <= 60 :
        print("Grade =C")
    else :
        print("Enter value between 0-100")
# Out:
# Grade = A

# %%
# For Loop
for i in range (6):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
for i in range (6):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range (6):
    if i == 3:
        pass  # No action
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
x = 6
while x > 0:
    print("python")
    x-=1
# Out:
# python
# python
# python
# python
# python
# python
