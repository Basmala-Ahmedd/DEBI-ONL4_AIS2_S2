# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 30
print("My Age is :",x)
# Out:
# My Age is : 30

# %%
print("My Name Is {} and My Age Is {}".format("Basmala",20))
print("My Name Is {1} and My Age Is {0}".format("Basmala",20)) # To Exchange them.
# Out:
# My Name Is Basmala and My Age Is 20
# My Name Is 20 and My Age Is Basmala

# %%
name = "Basmala"
age = 20
course_name = "Machine Learning & Data Science"
print(f"My name is {name}, and I am {age}, I Learn {course_name} ")
# Out:
# My name is Basmala, and I am 20, I Learn Machine Learning & Data Science

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = "DEPI"
print(x[-1])
print(x[2])
# Out:
# I
# P

# %%
# String_Slicing 
x = "DEPI"
print(x[0:2:2])
# Out:
# D

# %%
name = "depi Learning"
upper_txt = name.upper()
print (upper_txt)
# Out:
# DEPI LEARNING

# %%
lower_txt = upper_txt.lower()
lower_txt
# Out:
# 'depi learning'

# %%
name.replace("depi","depi_ml")
# Out:
# 'depi_ml Learning'

# %%
name = name.replace("depi","depi_ml")
print(name)
# Out:
# depi_ml Learning

# %%
name = "depi learning for machine learning depi"
name.count("depi")
# Out:
# 2

# %%
print(name.split())
x = name.split()
respone =' '.join(x)
respone
# Out:
# ['depi', 'learning', 'for', 'machine', 'learning', 'depi']
# 'depi learning for machine learning depi'

# %%
print ("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Welcome to depi \"Machine Learning Course\" ")
# Out:
# Welcome to depi "Machine Learning Course"

# %%
print("hello \tworld")
# Out:
# hello 	world

# %%
x = 2
X = 2
print(id(x))
print(id(X))
# Out:
# 140717514811864
# 140717514811864

# %%
# list => Can be any DataType. 
x = []
type(x)
# Out:
# list
