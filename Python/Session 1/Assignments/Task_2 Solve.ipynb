# %%
# Task_1 :
email = "Amit_ml@gmail.edu"
if email.count("@") != 1 or "." not in email.split("@")[1]:
    print ("Invalid Email")
else:
    User_Name = email.split("@")[0]
    Domain = email.split("@")[1].rsplit(".", 1)[0]
    print("Username:" + User_Name)
    print("Domain:" + Domain)
    if email.endswith(".com"):
        print ("Commercial Domain")
    elif email.endswith(".edu"):
        print("Educational Domain") 
    else:
        print("Other Domain")
# Out:
# Username:Amit_ml
# Domain:gmail
# Educational Domain

# %%
# Task _2 :
Encoded_message = "###!!@mocleW EPGTQ!!!6789"
Extracted_part = Encoded_message [6:18]
words = Extracted_part
first_word = words.split() [0][::-1]
second_word = words.split() [1][1:5]
print(first_word , second_word)
# Out:
# Welcom PGTQ

# %%
# Task_3:
Encoded_message = "&&&**$gnirtS PLIO!!@1234"
Extracted_part = Encoded_message [6:17]
words = Extracted_part
first_word = words.split() [0][::-1]
second_word = words.split() [1]
second_word = second_word.replace("I","E")
second_word = second_word.replace("O","U")
print(first_word , second_word)
# Out:
# String PLEU

# %%
# Task_4:
Encoded_message = "##$$$@!yalpstcejorp EPUVT****9887"
Extracted_part = Encoded_message [7:25]
words = Extracted_part
first_word = words.split() [0][::-1]
second_word = words.split() [1]
second_word = second_word.replace("E","A")
second_word = second_word.replace("U","O")
print(first_word , second_word)
# Out:
# projectsplay APOVT
