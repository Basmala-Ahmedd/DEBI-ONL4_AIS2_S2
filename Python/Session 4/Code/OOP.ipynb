# %%
"""

This Class 

"""
class StudentInfo:
    
    student_name = "Basmala"
    Student_age = 20
    Gpa = 3.9
    gender = "Female"
    
    def student_info():
        
        return f" Welcom into DEPI "

# %%
s1 = StudentInfo()
s1.student_name,
