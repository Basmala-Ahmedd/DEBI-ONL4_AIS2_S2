# %%
"""

This Class

"""
class StudentInfo ():
    
    student_name = "Basmala"
    student_age = 20
    gender = "Female"
    
    def student_info(self): # should put " self " to access the function. 
        
        print(self)

# %%
s1 = StudentInfo()
print(s1)
print(s1.student_info())
# Out:
# ...
# None
