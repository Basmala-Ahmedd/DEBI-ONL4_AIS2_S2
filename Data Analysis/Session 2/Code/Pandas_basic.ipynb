# %%
! pip install pandas

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4])
type(s)
s1= pd.Series([1,2,3,4], index = ['A','B','C','D'])

# %%
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,444,'xyz']
        ]
data_2 = {'ID':[1,2,3,4],
        'std_id_dict':[444,555,666,444],
        'dept': ['abc' , 'def' ,'ghi', 'xyz' ]}

df = pd.DataFrame(data,columns=['ID','std_id','Depi'])
df
# Out:
#    ID  std_id Depi
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     444  xyz

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Depi'], dtype='str')

# %%
index =['row1','row2','row3','row4']
df.index = index 
display(df)
# Out:
#       ID  std_id Depi
# row1   1     444  abc
# row2   2     555  def
# row3   3     666  ghi
# row4   4     444  xyz

# %%
class Person:
    def __init__(self,name):
        self.name = name
    @property
    def getInfo(self):
        return f"My Name is {self.name}"

# %%
p1 = Person("Basmala")
p1.getInfo
# Out:
# 'My Name is Basmala'

# %%
df.dtypes
# Out:
# ID        int64
# std_id    int64
# Depi        str
# dtype: object

# %%
df['Depi'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>
